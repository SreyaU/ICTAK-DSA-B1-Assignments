# %% [markdown]
# # Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading the dataset to python environment

# %%
iris_data = pd.read_excel(r'C:\Users\Sreya\Desktop\iris.xls')

# %% [markdown]
# # Displaying columns in the dataset

# %%
iris_data.head()
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %%
iris_data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %%
iris_data.shape
# Out:
# (150, 5)

# %%
iris_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SL              150 non-null    float64
#  1   SW              150 non-null    float64
#  2   PL              150 non-null    float64
#  3   PW              150 non-null    float64
#  4   Classification  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# # Finding mean of each column

# %%
iris_data[['SL','SW', 'PL', 'PW']].mean(axis=0)
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# # Checking for the null values

# %%
iris_data.isna().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %%
iris_data['Classification'].nunique()
# Out:
# 3

# %%
iris_data['Classification'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
iris_data['Classification']=iris_data['Classification'].str.replace('-',' ')

# %%
iris_data['Classification']=iris_data['Classification'].astype(str)

# %%
iris_data['Classification'].dtype
# Out:
# dtype('O')

# %% [markdown]
# # Visualizations

# %%
plt.bar(iris_data['SL'],iris_data['SW'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.bar(iris_data['PL'],iris_data['PW'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.pairplot(iris_data)

# %%
plt.hist(iris_data['Classification'],rwidth = 0.98, cumulative = True)
plt.title('Iris flower species')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data=iris_data[['SL','SW','PL','PW']]
sns.heatmap(data.corr(), annot = True)
# Out:
# <AxesSubplot: >
